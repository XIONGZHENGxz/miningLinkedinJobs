# %% [markdown]
# # <p style="text-align: center;">EE 380L: Data Mining</p>
# # <p style="text-align: center;">Assignment 1</p>
# ## <p style="text-align: center;">Total points: 30</p>
# ## <p style="text-align: center;">Due: Tuesday, Jan 31, 2017, submitted via Canvas by 11:59 pm</p>

# %% [markdown]
# # Question 1: Applications of Data Mining (5 pts)
#
# Find a technical article/publication of your interest (published in 2015 or later) that uses data mining for some engineering application and provide the citation.
#
# 1. (2 pts) What problem was addressed  and how did the data mining approach help solve the problem?
# 2. (3 pts) Which data mining (regression/classification/etc) model(s) was used in the article?  What were the criteria used in selecting the model?
#
#
# ## Answer
#
# 1. The paper is Data-Mining based Comprehensive Primary and Backup Protection Scheme for Micro-Grid. In this paper, data mining approach is used to identify a fault state of a micro-grid power system according to the set of features of the grid.
# 2. This paper uses decision tree model particularly classification tree to identify a fault state the grid. There are many features in a grid. Different features may indicate different state of the grid. Building a classification tree from existing dataset (features and states) will help decide whether the grid has failure or not given the current feature set of the grid. Classification tree is simple to understand and interpret. It could work both with small dataset and large dataset.

# %% [markdown]
# # Question 2: Maximum Likelihood Estimation (5 pts)
#
# Consider the following discrete univariate probability distribution involving a single parameter $\lambda$.
#
# $$P(k; \lambda) = \frac{\lambda^k e^{-\lambda}}{k!}, ~~~ k = 0, 1, 2, \ldots , $$, and zero elsewhere.
#
# Given N data points $x_1, x_2, \ldots x_N$ drawn i.i.d. from this distribution, derive the MLE estimate for $\lambda$, in terms of $x_1, x_2, \ldots x_N$.
#
# ## Answer
#
# $$ Log likelihood: LL=log{\prod_{i=1}^{N}{P(x_i;\lambda)}}$$
# $$ LL=\sum_{i=1}^{N}{x_i}log{\lambda}-N\lambda-log{\prod_{i=1}^{N}{x_i!}}$$
#
# In order to maximize log likelihood, we need to maximize:
# $$ f = \sum_{i=1}^{N}{x_i}log{\lambda}-N\lambda$$.
# $$f'=\frac{\sum_{i=1}^{N}{x_i}}{\lambda}-N$$
# So $$ \lambda = \frac{\sum_{i=1}^{N}{x_i}}{N}$$

# %% [markdown]
# # Question 3: Illustrating the "Curse of Dimensionality" (6 pts)
#
# Consider a hypersphere of radius $a$ in $d$ dimensions, circumscribed in a hypercube with sides of length $2a$.
# The ratio of the volume of a hypersphere to the the volumn of a hypercube is given by,
#
# $$f = \frac{\text{volume of sphere}}{\text{volume of cube}} = \frac{\pi^{d/2}}{d2^{d-1}\Gamma(d/2)}$$
#
# When $x$ is large, the gamma function $\Gamma$ can be approximated by the Stirling's approximation as follows.
#
# $$\Gamma(x+1) \simeq (2\pi )^{1/2}e^{-x}x^{x+1/2} $$
#
# a. (3 pts) Calculate the ratio $f$ for the cases $d$ = 10 and 100.  Note that for integers, $i, \Gamma(i) = (i-1)!$, so you don't need to use Stirling's approximation.
#
# b. (3 pts) What do your results say about where the volume is concentrated at in  high dimensional hypercubes?
#
# ## Answer
#
# a.
#
# (1) d=10
# $$ f= \frac{\pi^5}{10*2^9*\Gamma(5)}=\frac{\pi^5}{10*2^9*24}$$
#
# $$ f=0.25% $$
# (2) d=100
# $$ f=\frac{\pi^{50}}{100*2^{99}*\Gamma(50)}=\frac{\pi^{50}}{100*2^{99}*{49}!}=$$
#
# $$ f=1.87e-70% $$
#
# b.
#
# The results show indicate that in high dimensional hypercubes most of the volume is concentrated at marginal regions instead of the center, which is opposite to the case of low dimensinal.

# %% [markdown]
# # Question 4: Multiple Linear Regression in Python (14 pts)
#
# Use the following code to import the diabetes dataset and generalized linear models in python.

# %%
from sklearn import datasets, linear_model
diabetes = datasets.load_diabetes()

# %% [markdown]
# The dataset consists of ten features and one target variable.  More information is found at http://scikit-learn.org/stable/datasets/index.html#diabetes-dataset
#
# a. (2 pts) Print the shape (number of rows and columns) of the feature matrix, and print the first 5 rows. (Use shape and head commands in python).
#
# b. (2 pts) Visualize the relationship between the first four features (age, sex, body mass index, average blood pressure) and the response variable using scatterplots.  Comment on the fits.
#
# c.  (3 pts) Using ordinary least squares, fit a multiple linear regression (MLR) on all the feature variables using the entire dataset (442 rows). Report the regression coefficient of each input feature and evaluate the model using mean squared error (MSE).  Example of ordinary least squares in Python is shown in Section 1.1.1 of http://scikit-learn.org/stable/modules/linear_model.html.
#
# d.  (4 pts) Split the data into a training set and a test set.  Use the first 300 rows for training set and remaining rows for test set.  Fit an MLR using the training set.  Evaluate the trained model using the training set and the test set, respectively.  Compare the two MSE values thus obtained.
#
# e.  (3 pts) Do you think your MLR model is reasonable for this problem? You may look at the distribution of residuals to provide an informed answer.
#
# ## Answer

# %%
from sklearn import datasets, linear_model
diabetes = datasets.load_diabetes()

# a.
from pandas import DataFrame
d=diabetes.data
print 'The shape of feature matrix is:\n'
print d.shape
df=DataFrame(data=d)
print '\nThe first 5 rows of feature matrix is:\n'
print df.head(5)

# b.
import matplotlib.pyplot as plt
age=d[:,0]
sex=d[:,1]
body_mass_index=d[:,2]
average_blood_pressure=d[:,3]
target=diabetes.target

plt.figure()
plt.title("Relationship between age and target",fontsize='10')
plt.scatter(age,target,marker='*',c='green')

plt.figure()
plt.title("Relationship between sex and response variable",fontsize='10')
plt.scatter(sex,target,marker='o',c='red')

plt.figure()
plt.title("Relationship between body mass index and target",fontsize='10')
plt.scatter(body_mass_index,target,marker='+',c='blue')

plt.figure()
plt.title("relationship between average blood pressure and target",fontsize='10')
plt.scatter(average_blood_pressure,target,marker='*',c='yellow')


# c.
from sklearn import linear_model
from sklearn import metrics
import numpy as np
reg=linear_model.LinearRegression()
reg.fit(d,target)
print '\n\nThe coefficient of each feature is: '
print reg.coef_
coef=reg.coef_.reshape(10,1)
estimated_target=np.dot(d,coef)
MSE=metrics.mean_squared_error(estimated_target,target)
print '\nmean square error is:\n'
print MSE


# d.
training=df.head(300)
target_df=DataFrame(data=target)
target_train=target_df.head(300)
test=len(target)-300
target_test=target_df.tail(test)
testing=df.tail(test)
reg.fit(training,target_train)

print reg.coef_
coef=reg.coef_.reshape(10,1)
estimated_tar=np.dot(training,coef)
MSE_training=metrics.mean_squared_error(estimated_tar,target_train)
estimated_test=np.dot(testing,coef)
MSE_testing=metrics.mean_squared_error(estimated_test,target_test)
print '\ntraining set MSE:\n',MSE_training
print '\ntesting set MSE:\n',MSE_testing


# e.
residues=estimated_test-target_test
x=np.arange(test)
residue_mean=np.mean(residues)
residue_std=np.std(residues)
plt.figure()
plt.hist(residues,normed=True)
plt.show()
# Out:
# The shape of feature matrix is:
#
# (442, 10)
#
# The first 5 rows of feature matrix is:
#
#           0         1         2         3         4         5         6  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#           7         8         9
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641
#
#
# The coefficient of each feature is:
# [ -10.01219782 -239.81908937  519.83978679  324.39042769 -792.18416163
#   476.74583782  101.04457032  177.06417623  751.27932109   67.62538639]
#
# mean square error is:
#
# 26004.2874023
# [[ -16.57607993 -254.66532396  560.98630022  278.91811152 -393.41357305
#     97.05460405  -19.0023093   169.46450327  632.95050374  114.21638941]]
#
# training set MSE:
# 26132.8720238
#
# testing set MSE:
# 25801.1184141
